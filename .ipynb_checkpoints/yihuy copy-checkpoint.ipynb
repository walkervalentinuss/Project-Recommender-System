# %% [markdown]
# # Section 1 | Import Libraries and Load Data

# %%
# Data processing
import pandas as pd
import numpy as np
import scipy.stats

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Similarity and split
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("data\Tempat-Wisata-Toba-Preprocessing.csv")

# %%
data.shape
# Out:
# (43226, 9)

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'address', 'PlaceID',
#        'Nama_tempat_wisata', 'Category', 'ReviewerId', 'Rating', 'Reviews'],
#       dtype='object')

# %%
data = data.rename(columns={'ReviewerId': 'user_id', 'PlaceID': 'item_id', 'Rating': 'rating'})
# data['user_id'] = data['user_id'].astype(str)
# data['item_id'] = data['item_id'].astype(str)
data['rating'] = data['rating'].astype(float)
data.dropna(inplace=True)
data.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 1             1           1
# 3             3           3
# 4             4           4
# 6             6           6
# 8             8           8
#
#                                              address  item_id  \
# 1  Jl. Sibola Hotang, Sibola Hotangsas, Kec. Bali...        0
# 3  Jl. Sibola Hotang, Sibola Hotangsas, Kec. Bali...        0
# 4  Jl. Sibola Hotang, Sibola Hotangsas, Kec. Bali...        0
# 6  Jl. Sibola Hotang, Sibola Hotangsas, Kec. Bali...        0
# 8  Jl. Sibola Hotang, Sibola Hotangsas, Kec. Bali...        0
#
#           Nama_tempat_wisata       Category       user_id  rating  \
# 1  PASIR PUTIH LUMBAN BULBUL  Wisata Bahari  1.119090e+20     5.0
# 3  PASIR PUTIH LUMBAN BULBUL  Wisata Bahari  1.130720e+20     5.0
# 4  PASIR PUTIH LUMBAN BULBUL  Wisata Bahari  1.061730e+20     5.0
# 6  PASIR PUTIH LUMBAN BULBUL  Wisata Bahari  1.142390e+20     5.0
# 8  PASIR PUTIH LUMBAN BULBUL  Wisata Bahari  1.047430e+20     3.0
#
#                                              Reviews
# 1                                              bagus
# 3                                 sangat menyenagkan
# 4                      bebas foto dimana aja cuma 2k
# 6                         amazing pengen kesini lagi
# 8  jalan menuju lokasi perlu diperhatikan oleh pe...

# %%
data.shape
# Out:
# (22166, 9)

# %% [markdown]
# # Section 2 | Data Splitting

# %%
# Step 1: Split into 85% training+validation and 15% test
train_val_data, test_data = train_test_split(data, test_size=0.15, random_state=42)
# Step 2: Define validation size as 17% of train+validation, rounded up
val_size = int(len(train_val_data) * 0.17) + 1
# Step 3: Split 85% data into training (about 70% of original) and validation (about 15% of original)
train_data, val_data = train_test_split(train_val_data, test_size=val_size, random_state=42)
# Check sizes
print(f"Train data size: {train_data.shape}")
print(f"Validation data size: {val_data.shape}")
print(f"Test data size: {test_data.shape}")
# Out:
# Train data size: (15638, 9)
# Validation data size: (3203, 9)
# Test data size: (3325, 9)

# %% [markdown]
# # Section 3 | Create User-Item Matrix

# %%
def create_user_item_matrix(data, user_col='user_id', item_col='Nama_tempat_wisata', rating_col='rating'):
    data = data.groupby([user_col, item_col])[rating_col].mean().reset_index()
    return data.pivot(index=user_col, columns=item_col, values=rating_col).fillna(0)

# Apply the function to create matrices for each split
train_matrix = create_user_item_matrix(train_data)
val_matrix = create_user_item_matrix(val_data).reindex(columns=train_matrix.columns, fill_value=0)
test_matrix = create_user_item_matrix(test_data).reindex(columns=train_matrix.columns, fill_value=0)

# %%
train_matrix
# Out:
# Nama_tempat_wisata  Aek Rangat Pangururan  Aek Sipangolu Bakkara  \
# user_id
# 1.000030e+20                          0.0                    0.0
# 1.000040e+20                          0.0                    0.0
# 1.000090e+20                          0.0                    0.0
# 1.000100e+20                          0.0                    0.0
# 1.000120e+20                          0.0                    0.0
# ...                                   ...                    ...
# 1.184390e+20                          0.0                    0.0
# 1.184410e+20                          0.0                    0.0
# 1.184430e+20                          0.0                    0.0
# 1.184440e+20                          0.0                    0.0
# 1.184460e+20                          0.0                    0.0
#
# Nama_tempat_wisata  Air Terjun Efrata  Air Terjun Janji  Air Terjun Pandumaan  \
# user_id
# 1.000030e+20                      0.0               0.0                   0.0
# 1.000040e+20                      0.0               0.0                   0.0
# 1.000090e+20                      0.0               0.0                   0.0
# 1.000100e+20                      0.0               0.0                   0.0
# 1.000120e+20                      0.0               0.0                   0.0
# ...                               ...               ...                   ...
# 1.184390e+20                      0.0               0.0                   0.0
# 1.184410e+20                      0.0               0.0                   0.0
# 1.184430e+20                      0.0               0.0                   0.0
# 1.184440e+20                      0.0               0.0                   0.0
# 1.184460e+20                      0.0               0.0                   0.0
#
# Nama_tempat_wisata  Air Terjun Sampuran  Air Terjun Siboruon  \
# user_id
# 1.000030e+20                        0.0                  0.0
# 1.000040e+20                        0.0                  0.0
# 1.000090e+20                        0.0                  0.0
# 1.000100e+20                        0.0                  0.0
# 1.000120e+20                        0.0                  0.0
# ...                                 ...                  ...
# 1.184390e+20                        0.0                  0.0
# 1.184410e+20                        0.0                  0.0
# 1.184430e+20                        0.0                  0.0
# 1.184440e+20                        0.0                  0.0
# 1.184460e+20                        0.0                  0.0
#
# Nama_tempat_wisata  Air Terjun Situmurun  Air Terjun Taman Eden 100  \
# user_id
# 1.000030e+20                         0.0                        0.0
# 1.000040e+20                         0.0                        0.0
# 1.000090e+20                         0.0                        0.0
# 1.000100e+20                         0.0                        0.0
# 1.000120e+20                         0.0                        0.0
# ...                                  ...                        ...
# 1.184390e+20                         0.0                        0.0
# 1.184410e+20                         0.0                        0.0
# 1.184430e+20                         0.0                        0.0
# 1.184440e+20                         0.0                        0.0
# 1.184460e+20                         0.0                        0.0
#
# Nama_tempat_wisata  Air Terjun Tombak Pangaribuan  ...  Tao Silalahi Hotel  \
# user_id                                            ...
# 1.000030e+20                                  0.0  ...                 0.0
# 1.000040e+20                                  0.0  ...                 0.0
# 1.000090e+20                                  0.0  ...                 0.0
# 1.000100e+20                                  0.0  ...                 0.0
# 1.000120e+20                                  0.0  ...                 5.0
# ...                                           ...  ...                 ...
# 1.184390e+20                                  0.0  ...                 0.0
# 1.184410e+20                                  0.0  ...                 0.0
# 1.184430e+20                                  0.0  ...                 0.0
# 1.184440e+20                                  0.0  ...                 0.0
# 1.184460e+20                                  0.0  ...                 0.0
#
# Nama_tempat_wisata  Tarabunga  Tempat Pengasingan Soekarno  The Kaldera  \
# user_id
# 1.000030e+20              0.0                          0.0          0.0
# 1.000040e+20              0.0                          0.0          0.0
# 1.000090e+20              0.0                          0.0          0.0
# 1.000100e+20              0.0                          0.0          0.0
# 1.000120e+20              0.0                          0.0          0.0
# ...                       ...                          ...          ...
# 1.184390e+20              0.0                          0.0          0.0
# 1.184410e+20              0.0                          0.0          0.0
# 1.184430e+20              0.0                          0.0          0.0
# 1.184440e+20              0.0                          0.0          0.0
# 1.184460e+20              0.0                          0.0          0.0
#
# Nama_tempat_wisata  Tombak Sulusulu  Tugu D.I PANJAITAN  Tugu Toga Aritonang  \
# user_id
# 1.000030e+20                    0.0                 0.0                  0.0
# 1.000040e+20                    0.0                 0.0                  0.0
# 1.000090e+20                    0.0                 0.0                  0.0
# 1.000100e+20                    0.0                 0.0                  0.0
# 1.000120e+20                    0.0                 0.0                  0.0
# ...                             ...                 ...                  ...
# 1.184390e+20                    0.0                 0.0                  0.0
# 1.184410e+20                    0.0                 0.0                  0.0
# 1.184430e+20                    0.0                 0.0                  0.0
# 1.184440e+20                    0.0                 0.0                  0.0
# 1.184460e+20                    0.0                 0.0                  0.0
#
# Nama_tempat_wisata  WF Coffee&Resto  Wisata Bukit Gibeon  Wisata Rumah Pohon
# user_id
# 1.000030e+20                    0.0                  0.0                 0.0
# 1.000040e+20                    0.0                  0.0                 0.0
# 1.000090e+20                    0.0                  0.0                 0.0
# 1.000100e+20                    0.0                  0.0                 0.0
# 1.000120e+20                    0.0                  0.0                 0.0
# ...                             ...                  ...                 ...
# 1.184390e+20                    0.0                  0.0                 0.0
# 1.184410e+20                    0.0                  0.0                 0.0
# 1.184430e+20                    0.0                  0.0                 0.0
# 1.184440e+20                    0.0                  0.0                 0.0
# 1.184460e+20                    0.0                  0.0                 0.0
#
# [8905 rows x 98 columns]

# %% [markdown]
# # Define RMSE, MAE, MAP, Precision, & Recall Calculation Function

# %%
def compute_rmse(true_matrix, approx_matrix):
    return np.sqrt(mean_squared_error(true_matrix.ravel(), approx_matrix.ravel()))

# %%
def compute_map(true_matrix, pred_matrix, threshold=3):
    map_score = 0
    n_users = true_matrix.shape[0]
    
    for user_idx in range(n_users):
        true_ratings = true_matrix[user_idx] >= threshold  # Relevant items based on threshold
        pred_ratings = pred_matrix[user_idx]
        
        # Sort items by predicted rating (descending)
        sorted_items = np.argsort(pred_ratings)[::-1]
        
        # Precision at each relevant item
        precision_at_k = []
        relevant_items = 0
        for i, item_idx in enumerate(sorted_items):
            if true_ratings[item_idx]:
                relevant_items += 1
                precision_at_k.append(relevant_items / (i + 1))
        
        if precision_at_k:
            map_score += np.mean(precision_at_k)
    
    return map_score / n_users

# %%
def compute_precision_all_users(true_matrix, pred_matrix, threshold=3):
    precision_all_users = 0
    n_users = true_matrix.shape[0]
    
    for user_idx in range(n_users):
        true_ratings = true_matrix[user_idx] >= threshold  # Relevant items based on threshold
        pred_ratings = pred_matrix[user_idx] >= threshold  # Predicted items based on threshold
        
        # Compute Precision: the proportion of relevant items among predicted items
        relevant_predicted = np.sum(true_ratings & pred_ratings)  # True positives
        predicted_items = np.sum(pred_ratings)  # Total predicted items
        
        if predicted_items > 0:
            precision_all_users += relevant_predicted / predicted_items
        else:
            precision_all_users += 0
    
    return precision_all_users / n_users

# %%
def compute_recall_all_users(true_matrix, pred_matrix, threshold=3):
    recall_all_users = 0
    n_users = true_matrix.shape[0]
    
    for user_idx in range(n_users):
        true_ratings = true_matrix[user_idx] >= threshold  # Relevant items based on threshold
        pred_ratings = pred_matrix[user_idx] >= threshold  # Predicted items based on threshold
        
        # Compute Recall: the proportion of relevant items that are predicted
        relevant_predicted = np.sum(true_ratings & pred_ratings)  # True positives
        total_relevant_items = np.sum(true_ratings)  # Total relevant items
        
        if total_relevant_items > 0:
            recall_all_users += relevant_predicted / total_relevant_items
        else:
            recall_all_users += 0
    
    return recall_all_users / n_users

# %%
from sklearn.metrics import mean_absolute_error

def compute_mae(true_matrix, approx_matrix):
    return mean_absolute_error(true_matrix.ravel(), approx_matrix.ravel())

# %% [markdown]
# # SVD

# %% [markdown]
# ## No Tuning

# %%
from sklearn.decomposition import TruncatedSVD

# %%
n_factors = 10
svd = TruncatedSVD(n_components=n_factors, random_state=42)
U_train = svd.fit_transform(train_matrix)
Sigma = svd.components_

train_svd = svd.fit_transform(train_matrix)
train_approx_matrix = svd.inverse_transform(train_svd)

# %%
test_svd = svd.transform(test_matrix)
test_approx_matrix = svd.inverse_transform(test_svd)
test_rmse = compute_rmse(test_matrix.values, test_approx_matrix)
test_mae = compute_mae(test_matrix.values, test_approx_matrix)
test_map = compute_map(test_matrix.values, test_approx_matrix)
test_precision = compute_precision_all_users(test_matrix.values, test_approx_matrix)
test_recall = compute_recall_all_users(test_matrix.values, test_approx_matrix)

# %%
print("\n--- Test Evaluation ---")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Test MAP: {test_map:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
# Out:
# --- Test Evaluation ---
# Test RMSE: 0.3965
# Test MAE: 0.0765
# Test MAP: 0.4693
# Test Precision: 0.3393
# Test Recall: 0.3079

# %% [markdown]
# ## With Tuning

# %%
train_errors = {"factors": [], "rmse": [], "mae": [], "map": [], "precision": [], "recall": []}
val_errors = {"factors": [], "rmse": [], "mae": [], "map": [], "precision": [], "recall": []}

factors_range = range(5, 50, 5)  # Test different numbers of latent factors from 5 to 50

for n_factors in factors_range:
    svd = TruncatedSVD(n_components=n_factors, random_state=42)
    
    # Training
    train_svd = svd.fit_transform(train_matrix)
    train_approx_matrix = svd.inverse_transform(train_svd)
    train_rmse = compute_rmse(train_matrix.values, train_approx_matrix)
    train_mae = compute_mae(train_matrix.values, train_approx_matrix)
    train_map = compute_map(train_matrix.values, train_approx_matrix)
    train_precision = compute_precision_all_users(train_matrix.values, train_approx_matrix)
    train_recall = compute_recall_all_users(train_matrix.values, train_approx_matrix)
    
    # Simpan hasil training
    train_errors["factors"].append(n_factors)
    train_errors["rmse"].append(train_rmse)
    train_errors["mae"].append(train_mae)
    train_errors["map"].append(train_map)
    train_errors["precision"].append(train_precision)
    train_errors["recall"].append(train_recall)
    
    # Validation
    val_svd = svd.transform(val_matrix)
    val_approx_matrix = svd.inverse_transform(val_svd)
    val_rmse = compute_rmse(val_matrix.values, val_approx_matrix)
    val_mae = compute_mae(val_matrix.values, val_approx_matrix)
    val_map = compute_map(val_matrix.values, val_approx_matrix)
    val_precision = compute_precision_all_users(val_matrix.values, val_approx_matrix)
    val_recall = compute_recall_all_users(val_matrix.values, val_approx_matrix)
    
    # Simpan hasil validasi
    val_errors["factors"].append(n_factors)
    val_errors["rmse"].append(val_rmse)
    val_errors["mae"].append(val_mae)
    val_errors["map"].append(val_map)
    val_errors["precision"].append(val_precision)
    val_errors["recall"].append(val_recall)

# %%
plt.figure(figsize=(10, 6))
plt.plot(factors_range, train_errors["rmse"], label="Training RMSE", marker='o')
plt.plot(factors_range, val_errors["rmse"], label="Validation RMSE", marker='x')
plt.xlabel("Number of Latent Factors")
plt.ylabel("RMSE")
plt.legend()
plt.title("Training and Validation RMSE over Latent Factors")
plt.grid()
plt.show()

# %%
optimal_idx = val_errors["rmse"].index(min(val_errors["rmse"]))
optimal_factors = factors_range[optimal_idx]
print(f"Optimal Number of Factors: {optimal_factors}")
# Out:
# Optimal Number of Factors: 45

# %%
svd = TruncatedSVD(n_components=optimal_factors, random_state=42)
train_svd = svd.fit_transform(train_matrix)
train_approx_matrix = svd.inverse_transform(train_svd)

# %%
test_svd = svd.transform(test_matrix)
test_approx_matrix = svd.inverse_transform(test_svd)
final_test_rmse = compute_rmse(test_matrix.values, test_approx_matrix)
final_test_mae = compute_mae(test_matrix.values, test_approx_matrix)
final_test_map = compute_map(test_matrix.values, test_approx_matrix)
final_test_precision = compute_precision_all_users(test_matrix.values, test_approx_matrix)
final_test_recall = compute_recall_all_users(test_matrix.values, test_approx_matrix)

# %%
print("\n--- Final Test Evaluation ---")
print(f"Test RMSE: {final_test_rmse:.4f}")
print(f"Test MAE: {final_test_mae:.4f}")
print(f"Test MAP: {final_test_map:.4f}")
print(f"Test Precision: {final_test_precision:.4f}")
print(f"Test Recall: {final_test_recall:.4f}")
# Out:
# --- Final Test Evaluation ---
# Test RMSE: 0.1640
# Test MAE: 0.0171
# Test MAP: 0.8828
# Test Precision: 0.8231
# Test Recall: 0.8004

# %% [markdown]
# ## Comparison between no tuning & tuning SVD

# %%
metrics = ["RMSE", "MAE", "MAP", "Precision", "Recall"]
before_tuning = [test_rmse, test_mae, test_map, test_precision, test_recall]
after_tuning = [final_test_rmse, final_test_mae, final_test_map, final_test_precision, final_test_recall]

# %%
comparison_df = pd.DataFrame({
    "Metric" : metrics, 
    "Before Tuning" : before_tuning,
    "After Tuning" : after_tuning
})

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=comparison_df.melt(id_vars="Metric", var_name="Model", value_name="Score"),
            x="Metric", y="Score", hue="Model", palette="Blues")
# Out:
# <Axes: xlabel='Metric', ylabel='Score'>

# %% [markdown]
# ## Recommendation for user SVD

# %%
svd = TruncatedSVD(n_components=45, random_state=42)
matrix = svd.fit_transform(train_matrix.fillna(0))

# %%
reconstructed_matrix = np.dot(svd.transform(train_matrix.fillna(0)), svd.components_)
reconstructed_df = pd.DataFrame(reconstructed_matrix, index=train_matrix.index, columns=train_matrix.columns)

# %%
def recommend_places(user_id, original_df, predicted_df, top_n=3):
    """
    Menampilkan rekomendasi tempat untuk user tertentu.
    """
    # Tempat yang sudah diberi rating oleh user
    user_rated_places = original_df.loc[user_id]
    rated_places = user_rated_places[user_rated_places > 0].index.tolist()

    # Prediksi tempat untuk user
    user_predictions = predicted_df.loc[user_id]

    # Filter tempat yang belum dirating
    recommendations = user_predictions[~user_predictions.index.isin(rated_places)]
    
    # Urutkan berdasarkan prediksi tertinggi
    top_recommendations = recommendations.sort_values(ascending=False).head(top_n)
    
    return top_recommendations.index.tolist()

# %%
def print_recommendations(user_id, recommendations):
    """
    Menampilkan rekomendasi tempat dalam format list vertikal.
    """
    print(f"Rekomendasi untuk user {user_id}:")
    for i, place in enumerate(recommendations, start=1):
        print(f"{i}. {place}")

# %%
user_id = 1.000030e+20
recommendations = recommend_places(user_id, train_matrix, reconstructed_df, top_n=10)
print_recommendations(user_id, recommendations)
# Out:
# Rekomendasi untuk user 1.00003e+20:
# 1. Pantai Silalahi
# 2. Pesanggrahan Bung Karno
# 3. Kebun Raya Samosir, SUMUT
# 4. Taman Bunga Sapo Juma
# 5. Air Terjun Taman Eden 100
# 6. Patung Sigale gale
# 7. Bukit Senyum Motung
# 8. Objek Wisata Budaya Batu Kursi Raja Siallagan
# 9. Desa Meat
# 10. BUKIT GIBEON (YAPIM TARUNA)

# %%
user_id = 1.000040e+20
recommendations = recommend_places(user_id, train_matrix, reconstructed_df, top_n=10)
print_recommendations(user_id, recommendations)
# Out:
# Rekomendasi untuk user 1.00004e+20:
# 1. Bukit Burung
# 2. Pantai Silalahi
# 3. Kebun Raya Samosir, SUMUT
# 4. Bukit Holbung
# 5. Tombak Sulusulu
# 6. Caldera toba nomadic escape (glamour camping)
# 7. Taman Bunga Sapo Juma
# 8. Singgolom
# 9. Monumen Raja SONAKMALELA
# 10. Siregar Aek Nalas

# %% [markdown]
# # ALS

# %% [markdown]
# ## No Tuning

# %%
from numpy.linalg import solve

# %%
def als_train(ratings_matrix, n_factors=20, n_iterations=10, lambda_reg=0.1):
    # Initialize random P (user factors) and Q (item factors)
    n_users, n_items = ratings_matrix.shape
    P = np.random.rand(n_users, n_factors)
    Q = np.random.rand(n_items, n_factors)

    for iteration in range(n_iterations):
        # Fix Q and solve for P
        for u in range(n_users):
            # Select items rated by user u
            rated_items = ratings_matrix[u, :] > 0
            Q_rated = Q[rated_items]
            R_u = ratings_matrix[u, rated_items]
            
            # Solve for P[u]
            A = Q_rated.T @ Q_rated + lambda_reg * np.eye(n_factors)
            b = Q_rated.T @ R_u
            P[u] = solve(A, b)
        
        # Fix P and solve for Q
        for i in range(n_items):
            # Select users who rated item i
            rated_users = ratings_matrix[:, i] > 0
            P_rated = P[rated_users]
            R_i = ratings_matrix[rated_users, i]
            
            # Solve for Q[i]
            A = P_rated.T @ P_rated + lambda_reg * np.eye(n_factors)
            b = P_rated.T @ R_i
            Q[i] = solve(A, b)

        # Compute reconstruction error
        reconstruction = P @ Q.T
        error = np.sum((ratings_matrix[ratings_matrix > 0] - reconstruction[ratings_matrix > 0])**2)
        print(f"Iteration {iteration + 1}/{n_iterations}, Error: {error:.4f}")

    return P, Q

# %%
P_als_train, Q_als_train = als_train(train_matrix.values, n_factors=20, n_iterations=10, lambda_reg=0.1)
# Out:
# Iteration 1/10, Error: 4.0231
# Iteration 2/10, Error: 2.2544
# Iteration 3/10, Error: 1.6782
# Iteration 4/10, Error: 1.3623
# Iteration 5/10, Error: 1.1610
# Iteration 6/10, Error: 1.0219
# Iteration 7/10, Error: 0.9204
# Iteration 8/10, Error: 0.8440
# Iteration 9/10, Error: 0.7850
# Iteration 10/10, Error: 0.7385

# %%
P_als_test, Q_als_test = als_train(test_matrix.values, n_factors=20, n_iterations=10, lambda_reg=0.1)
# Out:
# Iteration 1/10, Error: 0.4205
# Iteration 2/10, Error: 0.4134
# Iteration 3/10, Error: 0.4052
# Iteration 4/10, Error: 0.4005
# Iteration 5/10, Error: 0.3977
# Iteration 6/10, Error: 0.3958
# Iteration 7/10, Error: 0.3945
# Iteration 8/10, Error: 0.3939
# Iteration 9/10, Error: 0.3943
# Iteration 10/10, Error: 0.3957

# %%
als_reconstruction_test = P_als_test @ Q_als_test.T

# %%
test_rmse = compute_rmse(test_matrix.values, als_reconstruction_test)
test_mae = compute_mae(test_matrix.values, als_reconstruction_test)
test_map = compute_map(test_matrix.values, als_reconstruction_test)
test_precision = compute_precision_all_users(test_matrix.values, als_reconstruction_test)
test_recall = compute_recall_all_users(test_matrix.values, als_reconstruction_test)

# %%
print("ALS Model Evaluation Results:")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Test MAP: {test_map:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
# Out:
# ALS Model Evaluation Results:
# Test RMSE: 2.8881
# Test MAE: 2.7288
# Test MAP: 0.8925
# Test Precision: 0.0490
# Test Recall: 0.9007

# %% [markdown]
# ## Tuning

# %%
for n_factors in factors_range:
    # Training ALS
    P_train, Q_train = als_train(train_matrix.values, n_factors=n_factors, n_iterations=10, lambda_reg=0.1)
    train_reconstruction = P_train @ Q_train.T
    
    train_rmse = compute_rmse(train_matrix.values, train_reconstruction)
    train_mae = compute_mae(train_matrix.values, train_reconstruction)
    train_map = compute_map(train_matrix.values, train_reconstruction)
    train_precision = compute_precision_all_users(train_matrix.values, train_reconstruction)
    train_recall = compute_recall_all_users(train_matrix.values, train_reconstruction)

    train_errors["factors"].append(n_factors)
    train_errors["rmse"].append(train_rmse)
    train_errors["mae"].append(train_mae)
    train_errors["map"].append(train_map)
    train_errors["precision"].append(train_precision)
    train_errors["recall"].append(train_recall)

    # Validation ALS
    P_val, Q_val = als_train(val_matrix.values, n_factors=n_factors, n_iterations=10, lambda_reg=0.1)
    val_reconstruction = P_val @ Q_val.T
    
    val_rmse = compute_rmse(val_matrix.values, val_reconstruction)
    val_mae = compute_mae(val_matrix.values, val_reconstruction)
    val_map = compute_map(val_matrix.values, val_reconstruction)
    val_precision = compute_precision_all_users(val_matrix.values, val_reconstruction)
    val_recall = compute_recall_all_users(val_matrix.values, val_reconstruction)

    val_errors["factors"].append(n_factors)
    val_errors["rmse"].append(val_rmse)
    val_errors["mae"].append(val_mae)
    val_errors["map"].append(val_map)
    val_errors["precision"].append(val_precision)
    val_errors["recall"].append(val_recall)
# Out:
# Iteration 1/10, Error: 1434.6042
# Iteration 2/10, Error: 814.1025
# Iteration 3/10, Error: 578.6446
# Iteration 4/10, Error: 449.2968
# Iteration 5/10, Error: 370.5371
# Iteration 6/10, Error: 318.3099
# Iteration 7/10, Error: 281.3887
# Iteration 8/10, Error: 253.8868
# Iteration 9/10, Error: 232.4888
# Iteration 10/10, Error: 215.2288
# Iteration 1/10, Error: 22.4937
# Iteration 2/10, Error: 5.3533
# Iteration 3/10, Error: 3.1755
# Iteration 4/10, Error: 2.2419
# Iteration 5/10, Error: 1.7283
# Iteration 6/10, Error: 1.4063
# Iteration 7/10, Error: 1.1872
# Iteration 8/10, Error: 1.0295
# Iteration 9/10, Error: 0.9116
# Iteration 10/10, Error: 0.8207
# Iteration 1/10, Error: 137.2229
# Iteration 2/10, Error: 61.9223
# Iteration 3/10, Error: 38.5449
# Iteration 4/10, Error: 27.2362
# Iteration 5/10, Error: 20.6179
# Iteration 6/10, Error: 16.3397
# Iteration 7/10, Error: 13.3961
# Iteration 8/10, Error: 11.2774
# Iteration 9/10, Error: 9.6966
# Iteration 10/10, Error: 8.4817
# Iteration 1/10, Error: 0.7313
# Iteration 2/10, Error: 0.4295
# Iteration 3/10, Error: 0.3404
# Iteration 4/10, Error: 0.2940
# Iteration 5/10, Error: 0.2707
# Iteration 6/10, Error: 0.2593
# Iteration 7/10, Error: 0.2537
# Iteration 8/10, Error: 0.2512
# Iteration 9/10, Error: 0.2507
# Iteration 10/10, Error: 0.2515
# Iteration 1/10, Error: 13.7623
# Iteration 2/10, Error: 7.2370
# Iteration 3/10, Error: 4.9347
# Iteration 4/10, Error: 3.7642
# Iteration 5/10, Error: 3.0519
# Iteration 6/10, Error: 2.5745
# Iteration 7/10, Error: 2.2340
# Iteration 8/10, Error: 1.9800
# Iteration 9/10, Error: 1.7841
# Iteration 10/10, Error: 1.6288
# Iteration 1/10, Error: 0.2768
# Iteration 2/10, Error: 0.2583
# Iteration 3/10, Error: 0.2522
# Iteration 4/10, Error: 0.2506
# Iteration 5/10, Error: 0.2515
# Iteration 6/10, Error: 0.2537
# Iteration 7/10, Error: 0.2566
# Iteration 8/10, Error: 0.2599
# Iteration 9/10, Error: 0.2634
# Iteration 10/10, Error: 0.2671
# Iteration 1/10, Error: 2.9744
# Iteration 2/10, Error: 1.8723
# Iteration 3/10, Error: 1.4191
# Iteration 4/10, Error: 1.1669
# Iteration 5/10, Error: 1.0053
# Iteration 6/10, Error: 0.8925
# Iteration 7/10, Error: 0.8094
# Iteration 8/10, Error: 0.7460
# Iteration 9/10, Error: 0.6969
# Iteration 10/10, Error: 0.6584
# Iteration 1/10, Error: 0.3852
# Iteration 2/10, Error: 0.3699
# Iteration 3/10, Error: 0.3590
# Iteration 4/10, Error: 0.3514
# Iteration 5/10, Error: 0.3471
# Iteration 6/10, Error: 0.3456
# Iteration 7/10, Error: 0.3455
# Iteration 8/10, Error: 0.3462
# Iteration 9/10, Error: 0.3474
# Iteration 10/10, Error: 0.3490
# Iteration 1/10, Error: 1.3109
# Iteration 2/10, Error: 0.9731
# Iteration 3/10, Error: 0.8020
# Iteration 4/10, Error: 0.6978
# Iteration 5/10, Error: 0.6263
# Iteration 6/10, Error: 0.5743
# Iteration 7/10, Error: 0.5357
# Iteration 8/10, Error: 0.5074
# Iteration 9/10, Error: 0.4864
# Iteration 10/10, Error: 0.4700
# Iteration 1/10, Error: 0.5719
# Iteration 2/10, Error: 0.5366
# Iteration 3/10, Error: 0.5095
# Iteration 4/10, Error: 0.4889
# Iteration 5/10, Error: 0.4728
# Iteration 6/10, Error: 0.4602
# Iteration 7/10, Error: 0.4514
# Iteration 8/10, Error: 0.4462
# Iteration 9/10, Error: 0.4433
# Iteration 10/10, Error: 0.4415
# Iteration 1/10, Error: 0.9509
# Iteration 2/10, Error: 0.7830
# Iteration 3/10, Error: 0.6803
# Iteration 4/10, Error: 0.6096
# Iteration 5/10, Error: 0.5587
# Iteration 6/10, Error: 0.5226
# Iteration 7/10, Error: 0.4972
# Iteration 8/10, Error: 0.4787
# Iteration 9/10, Error: 0.4646
# Iteration 10/10, Error: 0.4533
# Iteration 1/10, Error: 0.8661
# Iteration 2/10, Error: 0.7916
# Iteration 3/10, Error: 0.7345
# Iteration 4/10, Error: 0.6890
# Iteration 5/10, Error: 0.6519
# Iteration 6/10, Error: 0.6218
# Iteration 7/10, Error: 0.5984
# Iteration 8/10, Error: 0.5806
# Iteration 9/10, Error: 0.5671
# Iteration 10/10, Error: 0.5571
# Iteration 1/10, Error: 0.8440
# Iteration 2/10, Error: 0.7232
# Iteration 3/10, Error: 0.6443
# Iteration 4/10, Error: 0.5897
# Iteration 5/10, Error: 0.5504
# Iteration 6/10, Error: 0.5213
# Iteration 7/10, Error: 0.4988
# Iteration 8/10, Error: 0.4803
# Iteration 9/10, Error: 0.4659
# Iteration 10/10, Error: 0.4562
# Iteration 1/10, Error: 1.0839
# Iteration 2/10, Error: 0.9706
# Iteration 3/10, Error: 0.8903
# Iteration 4/10, Error: 0.8304
# Iteration 5/10, Error: 0.7850
# Iteration 6/10, Error: 0.7514
# Iteration 7/10, Error: 0.7258
# Iteration 8/10, Error: 0.7051
# Iteration 9/10, Error: 0.6879
# Iteration 10/10, Error: 0.6735
# Iteration 1/10, Error: 0.9317
# Iteration 2/10, Error: 0.8106
# Iteration 3/10, Error: 0.7245
# Iteration 4/10, Error: 0.6633
# Iteration 5/10, Error: 0.6201
# Iteration 6/10, Error: 0.5886
# Iteration 7/10, Error: 0.5647
# Iteration 8/10, Error: 0.5463
# Iteration 9/10, Error: 0.5319
# Iteration 10/10, Error: 0.5204
# Iteration 1/10, Error: 1.3677
# Iteration 2/10, Error: 1.2043
# Iteration 3/10, Error: 1.0898
# Iteration 4/10, Error: 1.0093
# Iteration 5/10, Error: 0.9533
# Iteration 6/10, Error: 0.9111
# Iteration 7/10, Error: 0.8767
# Iteration 8/10, Error: 0.8479
# Iteration 9/10, Error: 0.8233
# Iteration 10/10, Error: 0.8023
# Iteration 1/10, Error: 0.9595
# Iteration 2/10, Error: 0.8324
# Iteration 3/10, Error: 0.7467
# Iteration 4/10, Error: 0.6901
# Iteration 5/10, Error: 0.6529
# Iteration 6/10, Error: 0.6262
# Iteration 7/10, Error: 0.6049
# Iteration 8/10, Error: 0.5873
# Iteration 9/10, Error: 0.5727
# Iteration 10/10, Error: 0.5608
# Iteration 1/10, Error: 1.7714
# Iteration 2/10, Error: 1.5269
# Iteration 3/10, Error: 1.3563
# Iteration 4/10, Error: 1.2331
# Iteration 5/10, Error: 1.1429
# Iteration 6/10, Error: 1.0777
# Iteration 7/10, Error: 1.0275
# Iteration 8/10, Error: 0.9862
# Iteration 9/10, Error: 0.9513
# Iteration 10/10, Error: 0.9212

# %%
P_als_test, Q_als_test = als_train(test_matrix.values, n_factors=10, n_iterations=10, lambda_reg=0.1)
# Out:
# Iteration 1/10, Error: 1.0591
# Iteration 2/10, Error: 0.4762
# Iteration 3/10, Error: 0.3652
# Iteration 4/10, Error: 0.3180
# Iteration 5/10, Error: 0.2929
# Iteration 6/10, Error: 0.2777
# Iteration 7/10, Error: 0.2686
# Iteration 8/10, Error: 0.2639
# Iteration 9/10, Error: 0.2621
# Iteration 10/10, Error: 0.2624

# %%
als_reconstruction_test = P_als_test @ Q_als_test.T

# %%
test_rmse = compute_rmse(test_matrix.values, als_reconstruction_test)
test_mae = compute_mae(test_matrix.values, als_reconstruction_test)
test_map = compute_map(test_matrix.values, als_reconstruction_test)
test_precision = compute_precision_all_users(test_matrix.values, als_reconstruction_test)
test_recall = compute_recall_all_users(test_matrix.values, als_reconstruction_test)

# %%
print("ALS Model Evaluation Results:")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Test MAP: {test_map:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
# Out:
# ALS Model Evaluation Results:
# Test RMSE: 2.6790
# Test MAE: 2.4624
# Test MAP: 0.8600
# Test Precision: 0.0492
# Test Recall: 0.9007

# %%
iterations_range = [5, 10, 20, 30]
lambda_range = [0.01, 0.05, 0.1, 0.5, 1.0]

# %%
best_rmse = float('inf')
best_n_iterations = None
best_lambda_reg = None

# %%
hyperparameter_errors = {
    "iterations": [],
    "lambda_reg": [],
    "rmse": [],
    "mae": [],
    "map": [],
    "precision": [],
    "recall": []
}

# %%
for n_iter in iterations_range:
    for lambda_val in lambda_range:
        # Training ALS dengan kombinasi hyperparameter
        P_train, Q_train = als_train(train_matrix.values, n_factors=10, n_iterations=n_iter, lambda_reg=lambda_val)
        train_reconstruction = P_train @ Q_train.T
        
        train_rmse = compute_rmse(train_matrix.values, train_reconstruction)
        train_mae = compute_mae(train_matrix.values, train_reconstruction)
        train_map = compute_map(train_matrix.values, train_reconstruction)
        train_precision = compute_precision_all_users(train_matrix.values, train_reconstruction)
        train_recall = compute_recall_all_users(train_matrix.values, train_reconstruction)

        # Simpan hasil
        hyperparameter_errors["iterations"].append(n_iter)
        hyperparameter_errors["lambda_reg"].append(lambda_val)
        hyperparameter_errors["rmse"].append(train_rmse)
        hyperparameter_errors["mae"].append(train_mae)
        hyperparameter_errors["map"].append(train_map)
        hyperparameter_errors["precision"].append(train_precision)
        hyperparameter_errors["recall"].append(train_recall)

        # Simpan parameter terbaik berdasarkan RMSE
        if train_rmse < best_rmse:
            best_rmse = train_rmse
            best_n_iterations = n_iter
            best_lambda_reg = lambda_val
# Out:
# Iteration 1/5, Error: 35.9842
# Iteration 2/5, Error: 13.9123
# Iteration 3/5, Error: 7.7518
# Iteration 4/5, Error: 4.9855
# Iteration 5/5, Error: 3.4094
# Iteration 1/5, Error: 66.2987
# Iteration 2/5, Error: 26.2487
# Iteration 3/5, Error: 16.2470
# Iteration 4/5, Error: 11.6269
# Iteration 5/5, Error: 8.9727
# Iteration 1/5, Error: 115.2770
# Iteration 2/5, Error: 50.8960
# Iteration 3/5, Error: 31.8402
# Iteration 4/5, Error: 22.4646
# Iteration 5/5, Error: 17.0114
# Iteration 1/5, Error: 497.7195
# Iteration 2/5, Error: 187.2992
# Iteration 3/5, Error: 123.3633
# Iteration 4/5, Error: 91.6346
# Iteration 5/5, Error: 72.7859
# Iteration 1/5, Error: 850.4036
# Iteration 2/5, Error: 286.9444
# Iteration 3/5, Error: 201.6989
# Iteration 4/5, Error: 158.8804
# Iteration 5/5, Error: 133.4434
# Iteration 1/10, Error: 44.2517
# Iteration 2/10, Error: 18.2005
# Iteration 3/10, Error: 9.2381
# Iteration 4/10, Error: 5.8277
# Iteration 5/10, Error: 4.0801
# Iteration 6/10, Error: 3.0885
# Iteration 7/10, Error: 2.4608
# Iteration 8/10, Error: 2.0290
# Iteration 9/10, Error: 1.7148
# Iteration 10/10, Error: 1.4772
# Iteration 1/10, Error: 89.0590
# Iteration 2/10, Error: 38.1480
# Iteration 3/10, Error: 23.0476
# Iteration 4/10, Error: 15.9593
# Iteration 5/10, Error: 12.0024
# Iteration 6/10, Error: 9.5135
# Iteration 7/10, Error: 7.8142
# Iteration 8/10, Error: 6.5891
# Iteration 9/10, Error: 5.6705
# Iteration 10/10, Error: 4.9604
# Iteration 1/10, Error: 100.7443
# Iteration 2/10, Error: 47.3864
# Iteration 3/10, Error: 30.4213
# Iteration 4/10, Error: 22.0409
# Iteration 5/10, Error: 17.0616
# Iteration 6/10, Error: 13.7846
# Iteration 7/10, Error: 11.4892
# Iteration 8/10, Error: 9.8103
# Iteration 9/10, Error: 8.5397
# Iteration 10/10, Error: 7.5505
# Iteration 1/10, Error: 403.3929
# Iteration 2/10, Error: 157.9602
# Iteration 3/10, Error: 106.1949
# Iteration 4/10, Error: 81.2823
# Iteration 5/10, Error: 66.4027
# Iteration 6/10, Error: 56.4108
# Iteration 7/10, Error: 49.2059
# Iteration 8/10, Error: 43.7722
# Iteration 9/10, Error: 39.5539
# Iteration 10/10, Error: 36.2135
# Iteration 1/10, Error: 942.9095
# Iteration 2/10, Error: 295.4368
# Iteration 3/10, Error: 202.4384
# Iteration 4/10, Error: 157.4201
# Iteration 5/10, Error: 131.4205
# Iteration 6/10, Error: 115.0695
# Iteration 7/10, Error: 104.2688
# Iteration 8/10, Error: 96.9177
# Iteration 9/10, Error: 91.8326
# Iteration 10/10, Error: 88.2994
# Iteration 1/20, Error: 31.1696
# Iteration 2/20, Error: 8.0693
# Iteration 3/20, Error: 4.7003
# Iteration 4/20, Error: 3.3311
# Iteration 5/20, Error: 2.5818
# Iteration 6/20, Error: 2.1061
# Iteration 7/20, Error: 1.7759
# Iteration 8/20, Error: 1.5327
# Iteration 9/20, Error: 1.3458
# Iteration 10/20, Error: 1.1978
# Iteration 11/20, Error: 1.0775
# Iteration 12/20, Error: 0.9780
# Iteration 13/20, Error: 0.8944
# Iteration 14/20, Error: 0.8231
# Iteration 15/20, Error: 0.7616
# Iteration 16/20, Error: 0.7081
# Iteration 17/20, Error: 0.6610
# Iteration 18/20, Error: 0.6193
# Iteration 19/20, Error: 0.5821
# Iteration 20/20, Error: 0.5487
# Iteration 1/20, Error: 57.8354
# Iteration 2/20, Error: 28.1504
# Iteration 3/20, Error: 17.1846
# Iteration 4/20, Error: 11.8651
# Iteration 5/20, Error: 8.9083
# Iteration 6/20, Error: 7.0889
# Iteration 7/20, Error: 5.8750
# Iteration 8/20, Error: 5.0119
# Iteration 9/20, Error: 4.3677
# Iteration 10/20, Error: 3.8687
# Iteration 11/20, Error: 3.4709
# Iteration 12/20, Error: 3.1467
# Iteration 13/20, Error: 2.8775
# Iteration 14/20, Error: 2.6505
# Iteration 15/20, Error: 2.4567
# Iteration 16/20, Error: 2.2893
# Iteration 17/20, Error: 2.1433
# Iteration 18/20, Error: 2.0150
# Iteration 19/20, Error: 1.9013
# Iteration 20/20, Error: 1.7998
# Iteration 1/20, Error: 145.6298
# Iteration 2/20, Error: 65.7148
# Iteration 3/20, Error: 40.7176
# Iteration 4/20, Error: 28.5826
# Iteration 5/20, Error: 21.5386
# Iteration 6/20, Error: 17.0172
# Iteration 7/20, Error: 13.9277
# Iteration 8/20, Error: 11.7229
# Iteration 9/20, Error: 10.0908
# Iteration 10/20, Error: 8.8427
# Iteration 11/20, Error: 7.8613
# Iteration 12/20, Error: 7.0715
# Iteration 13/20, Error: 6.4236
# Iteration 14/20, Error: 5.8833
# Iteration 15/20, Error: 5.4265
# Iteration 16/20, Error: 5.0356
# Iteration 17/20, Error: 4.6977
# Iteration 18/20, Error: 4.4029
# Iteration 19/20, Error: 4.1438
# Iteration 20/20, Error: 3.9145
# Iteration 1/20, Error: 458.6643
# Iteration 2/20, Error: 167.8991
# Iteration 3/20, Error: 112.9139
# Iteration 4/20, Error: 85.5547
# Iteration 5/20, Error: 69.1364
# Iteration 6/20, Error: 58.2319
# Iteration 7/20, Error: 50.5197
# Iteration 8/20, Error: 44.8213
# Iteration 9/20, Error: 40.4699
# Iteration 10/20, Error: 37.0621
# Iteration 11/20, Error: 34.3410
# Iteration 12/20, Error: 32.1345
# Iteration 13/20, Error: 30.3233
# Iteration 14/20, Error: 28.8215
# Iteration 15/20, Error: 27.5657
# Iteration 16/20, Error: 26.5079
# Iteration 17/20, Error: 25.6111
# Iteration 18/20, Error: 24.8469
# Iteration 19/20, Error: 24.1926
# Iteration 20/20, Error: 23.6308
# Iteration 1/20, Error: 873.5284
# Iteration 2/20, Error: 296.4258
# Iteration 3/20, Error: 206.8005
# Iteration 4/20, Error: 162.3724
# Iteration 5/20, Error: 136.1353
# Iteration 6/20, Error: 119.2515
# Iteration 7/20, Error: 107.8606
# Iteration 8/20, Error: 99.9757
# Iteration 9/20, Error: 94.4523
# Iteration 10/20, Error: 90.5758
# Iteration 11/20, Error: 87.8734
# Iteration 12/20, Error: 86.0197
# Iteration 13/20, Error: 84.7849
# Iteration 14/20, Error: 84.0037
# Iteration 15/20, Error: 83.5568
# Iteration 16/20, Error: 83.3576
# Iteration 17/20, Error: 83.3441
# Iteration 18/20, Error: 83.4704
# Iteration 19/20, Error: 83.7020
# Iteration 20/20, Error: 84.0121
# Iteration 1/30, Error: 36.2440
# Iteration 2/30, Error: 11.6806
# Iteration 3/30, Error: 7.1737
# Iteration 4/30, Error: 5.1322
# Iteration 5/30, Error: 3.9077
# Iteration 6/30, Error: 3.0872
# Iteration 7/30, Error: 2.5079
# Iteration 8/30, Error: 2.0854
# Iteration 9/30, Error: 1.7692
# Iteration 10/30, Error: 1.5275
# Iteration 11/30, Error: 1.3388
# Iteration 12/30, Error: 1.1889
# Iteration 13/30, Error: 1.0676
# Iteration 14/30, Error: 0.9680
# Iteration 15/30, Error: 0.8849
# Iteration 16/30, Error: 0.8146
# Iteration 17/30, Error: 0.7543
# Iteration 18/30, Error: 0.7021
# Iteration 19/30, Error: 0.6564
# Iteration 20/30, Error: 0.6160
# Iteration 21/30, Error: 0.5800
# Iteration 22/30, Error: 0.5477
# Iteration 23/30, Error: 0.5184
# Iteration 24/30, Error: 0.4918
# Iteration 25/30, Error: 0.4675
# Iteration 26/30, Error: 0.4452
# Iteration 27/30, Error: 0.4246
# Iteration 28/30, Error: 0.4056
# Iteration 29/30, Error: 0.3880
# Iteration 30/30, Error: 0.3716
# Iteration 1/30, Error: 87.8164
# Iteration 2/30, Error: 37.6479
# Iteration 3/30, Error: 20.9178
# Iteration 4/30, Error: 13.6516
# Iteration 5/30, Error: 9.8909
# Iteration 6/30, Error: 7.6647
# Iteration 7/30, Error: 6.2180
# Iteration 8/30, Error: 5.2122
# Iteration 9/30, Error: 4.4764
# Iteration 10/30, Error: 3.9167
# Iteration 11/30, Error: 3.4777
# Iteration 12/30, Error: 3.1250
# Iteration 13/30, Error: 2.8359
# Iteration 14/30, Error: 2.5950
# Iteration 15/30, Error: 2.3915
# Iteration 16/30, Error: 2.2175
# Iteration 17/30, Error: 2.0673
# Iteration 18/30, Error: 1.9364
# Iteration 19/30, Error: 1.8213
# Iteration 20/30, Error: 1.7195
# Iteration 21/30, Error: 1.6288
# Iteration 22/30, Error: 1.5475
# Iteration 23/30, Error: 1.4743
# Iteration 24/30, Error: 1.4079
# Iteration 25/30, Error: 1.3476
# Iteration 26/30, Error: 1.2925
# Iteration 27/30, Error: 1.2420
# Iteration 28/30, Error: 1.1955
# Iteration 29/30, Error: 1.1525
# Iteration 30/30, Error: 1.1127
# Iteration 1/30, Error: 146.5766
# Iteration 2/30, Error: 66.0624
# Iteration 3/30, Error: 42.1404
# Iteration 4/30, Error: 30.0945
# Iteration 5/30, Error: 22.7317
# Iteration 6/30, Error: 17.8294
# Iteration 7/30, Error: 14.4182
# Iteration 8/30, Error: 11.9711
# Iteration 9/30, Error: 10.1642
# Iteration 10/30, Error: 8.7925
# Iteration 11/30, Error: 7.7253
# Iteration 12/30, Error: 6.8768
# Iteration 13/30, Error: 6.1896
# Iteration 14/30, Error: 5.6240
# Iteration 15/30, Error: 5.1518
# Iteration 16/30, Error: 4.7525
# Iteration 17/30, Error: 4.4113
# Iteration 18/30, Error: 4.1166
# Iteration 19/30, Error: 3.8600
# Iteration 20/30, Error: 3.6348
# Iteration 21/30, Error: 3.4355
# Iteration 22/30, Error: 3.2582
# Iteration 23/30, Error: 3.0995
# Iteration 24/30, Error: 2.9568
# Iteration 25/30, Error: 2.8278
# Iteration 26/30, Error: 2.7107
# Iteration 27/30, Error: 2.6039
# Iteration 28/30, Error: 2.5060
# Iteration 29/30, Error: 2.4158
# Iteration 30/30, Error: 2.3325
# Iteration 1/30, Error: 501.8178
# Iteration 2/30, Error: 180.3280
# Iteration 3/30, Error: 118.0078
# Iteration 4/30, Error: 87.4354
# Iteration 5/30, Error: 69.5263
# Iteration 6/30, Error: 57.9046
# Iteration 7/30, Error: 49.8266
# Iteration 8/30, Error: 43.9285
# Iteration 9/30, Error: 39.4651
# Iteration 10/30, Error: 35.9974
# Iteration 11/30, Error: 33.2496
# Iteration 12/30, Error: 31.0394
# Iteration 13/30, Error: 29.2419
# Iteration 14/30, Error: 27.7686
# Iteration 15/30, Error: 26.5537
# Iteration 16/30, Error: 25.5466
# Iteration 17/30, Error: 24.7078
# Iteration 18/30, Error: 24.0062
# Iteration 19/30, Error: 23.4175
# Iteration 20/30, Error: 22.9223
# Iteration 21/30, Error: 22.5059
# Iteration 22/30, Error: 22.1563
# Iteration 23/30, Error: 21.8643
# Iteration 24/30, Error: 21.6223
# Iteration 25/30, Error: 21.4239
# Iteration 26/30, Error: 21.2637
# Iteration 27/30, Error: 21.1367
# Iteration 28/30, Error: 21.0386
# Iteration 29/30, Error: 20.9656
# Iteration 30/30, Error: 20.9142
# Iteration 1/30, Error: 919.8443
# Iteration 2/30, Error: 290.2432
# Iteration 3/30, Error: 201.2371
# Iteration 4/30, Error: 157.3653
# Iteration 5/30, Error: 132.0018
# Iteration 6/30, Error: 115.9901
# Iteration 7/30, Error: 105.3212
# Iteration 8/30, Error: 97.9622
# Iteration 9/30, Error: 92.7667
# Iteration 10/30, Error: 89.0389
# Iteration 11/30, Error: 86.3541
# Iteration 12/30, Error: 84.4678
# Iteration 13/30, Error: 83.2187
# Iteration 14/30, Error: 82.4577
# Iteration 15/30, Error: 82.0517
# Iteration 16/30, Error: 81.9006
# Iteration 17/30, Error: 81.9337
# Iteration 18/30, Error: 82.1017
# Iteration 19/30, Error: 82.3692
# Iteration 20/30, Error: 82.7110
# Iteration 21/30, Error: 83.1084
# Iteration 22/30, Error: 83.5477
# Iteration 23/30, Error: 84.0189
# Iteration 24/30, Error: 84.5145
# Iteration 25/30, Error: 85.0294
# Iteration 26/30, Error: 85.5598
# Iteration 27/30, Error: 86.1033
# Iteration 28/30, Error: 86.6580
# Iteration 29/30, Error: 87.2220
# Iteration 30/30, Error: 87.7931

# %%
print(f"Best n_iterations: {best_n_iterations}")
print(f"Best lambda_reg: {best_lambda_reg}")
print(f"Best RMSE: {best_rmse:.4f}")
# Out:
# Best n_iterations: 30
# Best lambda_reg: 0.5
# Best RMSE: 1.9766

# %%
P_als_test, Q_als_test = als_train(test_matrix.values, n_factors=10, n_iterations=30, lambda_reg=0.5)
# Out:
# Iteration 1/30, Error: 18.6788
# Iteration 2/30, Error: 8.7614
# Iteration 3/30, Error: 8.3579
# Iteration 4/30, Error: 8.6349
# Iteration 5/30, Error: 9.1527
# Iteration 6/30, Error: 9.7564
# Iteration 7/30, Error: 10.3787
# Iteration 8/30, Error: 10.9882
# Iteration 9/30, Error: 11.5735
# Iteration 10/30, Error: 12.1314
# Iteration 11/30, Error: 12.6608
# Iteration 12/30, Error: 13.1620
# Iteration 13/30, Error: 13.6363
# Iteration 14/30, Error: 14.0854
# Iteration 15/30, Error: 14.5110
# Iteration 16/30, Error: 14.9149
# Iteration 17/30, Error: 15.2986
# Iteration 18/30, Error: 15.6636
# Iteration 19/30, Error: 16.0112
# Iteration 20/30, Error: 16.3425
# Iteration 21/30, Error: 16.6586
# Iteration 22/30, Error: 16.9603
# Iteration 23/30, Error: 17.2482
# Iteration 24/30, Error: 17.5232
# Iteration 25/30, Error: 17.7858
# Iteration 26/30, Error: 18.0367
# Iteration 27/30, Error: 18.2765
# Iteration 28/30, Error: 18.5056
# Iteration 29/30, Error: 18.7247
# Iteration 30/30, Error: 18.9343

# %%
als_reconstruction_test = P_als_test @ Q_als_test.T

# %%
final_test_rmse = compute_rmse(test_matrix.values, als_reconstruction_test)
final_test_mae = compute_mae(test_matrix.values, als_reconstruction_test)
final_test_map = compute_map(test_matrix.values, als_reconstruction_test)
final_test_precision = compute_precision_all_users(test_matrix.values, als_reconstruction_test)
final_test_recall = compute_recall_all_users(test_matrix.values, als_reconstruction_test)

# %%
print("ALS Model Evaluation Results:")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Test MAP: {test_map:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
# Out:
# ALS Model Evaluation Results:
# Test RMSE: 2.6790
# Test MAE: 2.4624
# Test MAP: 0.8600
# Test Precision: 0.0492
# Test Recall: 0.9007

# %% [markdown]
# ## Comparison between no tuning & tuning ALS

# %%
metrics = ["RMSE", "MAE", "MAP", "Precision", "Recall"]
before_tuning = [test_rmse, test_mae, test_map, test_precision, test_recall]
after_tuning = [final_test_rmse, final_test_mae, final_test_map, final_test_precision, final_test_recall]

# %%
comparison_df = pd.DataFrame({
    "Metric" : metrics, 
    "Before Tuning" : before_tuning,
    "After Tuning" : after_tuning
})

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=comparison_df.melt(id_vars="Metric", var_name="Model", value_name="Score"),
            x="Metric", y="Score", hue="Model", palette="Blues")
# Out:
# <Axes: xlabel='Metric', ylabel='Score'>

# %% [markdown]
# # BERT

# %% [markdown]
# # Visualisasi
